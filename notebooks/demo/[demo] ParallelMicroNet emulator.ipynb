# %%
import sys
dir_repo = '../../'
sys.path.append(dir_repo)

from emu_Nx2pt.utils import get_config_from_yaml
from emu_Nx2pt.mlp_emulator import MLP_Emulator

! rm -rf /home/hhg/Research/emu_Nx2pt/repo/emulator_Nx2pt/experiments/mlp_test/

# %%
config = get_config_from_yaml(dir_repo+'configs/mlp_test.yaml')
config.model_type = 'ParallelMicroNets'
config.encode_size = 32
config.hidden_size = 32
config.Nblocks = 1
config.output_size = [25]*97

emu = MLP_Emulator(config=config)
# Out:
# ------ Parameters ------
#
# exp_name : mlp_test
# cuda : True
# ngpu : 1
# gpu_device : 0
# workers : 16
# dir_output : /home/hhg/Research/emu_Nx2pt/repo/emulator_Nx2pt/experiments
# dir_dataT : {'train': '/home/hhg/Research/emu_Nx2pt/data/dataT_1M/', 'valid': '/home/hhg/Research/emu_Nx2pt/data/dataT_0.1M/'}
# file_pco : {'train': '/home/hhg/Research/emu_Nx2pt/data/pco_1M.pkl', 'valid': '/home/hhg/Research/emu_Nx2pt/data/pco_0.1M.pkl'}
# file_model_state : None
# startID : 0
# endID : 2425
# model_type : ParallelMicroNets
# output_size : [25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25]
# hidden_size : 32
# encode_size : 32
# Nblocks : 1
# is_batchNorm : False
# scale_factor : 1
# num_epochs : 10
# batch_size : 128
# lr : 0.001
# beta1 : 0.5
# beta2 : 0.999
# step_size : 10
# gamma : 0.1
# early_stop_threshold : 10
# file_cov : /home/hhg/Research/emu_Nx2pt/data/cov3500.pkl
# file_mask : /home/hhg/Research/emu_Nx2pt/data/10x2pt_RomanxSO_fid_mask.txt
#
# ------ Device ------
#
# cuda:0
#
# ------ Prepare Data ------
#
# Number of train samples: 1000000 (7813 batches)
# Number of valid samples: 100000 (782 batches)
#
# ------ Build Model ------
#
# ParallelMicroNets(
#   (par_layer): Sequential(
#     (0): Linear(in_features=17, out_features=32, bias=True)
#     (1): ReLU()
#   )
#   (microNets): ModuleDict(
#     (net_0): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_1): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_2): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_3): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_4): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_5): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_6): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_7): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_8): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_9): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_10): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_11): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_12): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_13): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_14): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_15): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_16): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_17): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_18): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_19): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_20): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_21): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_22): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_23): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_24): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_25): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_26): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_27): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_28): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_29): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_30): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_31): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_32): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_33): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_34): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_35): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_36): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_37): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_38): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_39): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_40): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_41): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_42): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_43): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_44): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_45): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_46): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_47): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_48): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_49): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_50): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_51): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_52): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_53): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_54): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_55): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_56): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_57): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_58): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_59): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_60): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_61): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_62): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_63): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_64): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_65): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_66): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_67): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_68): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_69): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_70): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_71): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_72): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_73): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_74): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_75): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_76): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_77): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_78): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_79): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_80): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_81): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_82): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_83): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_84): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_85): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_86): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_87): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_88): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_89): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_90): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_91): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_92): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_93): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_94): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_95): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#     (net_96): ModuleList(
#       (0): Res_Block(
#         (layer1): Linear(in_features=32, out_features=32, bias=True)
#         (layer2): Linear(in_features=32, out_features=32, bias=True)
#         (skip_layer): Identity()
#       )
#       (1): Linear(in_features=32, out_features=25, bias=True)
#     )
#   )
# )
#
# Number of trainable parameters: 285465
# ... Initialized model with random parameters.

# %%
emu.train()
# Out:
# ------ Create experiment directory ------
#
# Training information will be stored at :
#  	 /home/hhg/Research/emu_Nx2pt/repo/emulator_Nx2pt/experiments/mlp_test
# --- Epoch 1/10 ---
# 	train avg_chi2: 28011.94	valid avg_chi2: 6828.72	Time: 12m 56s
# --- Epoch 2/10 ---
# 	train avg_chi2: 5221.45	valid avg_chi2: 4840.04	Time: 12m 55s
# --- Epoch 3/10 ---
# 	train avg_chi2: 3696.30	valid avg_chi2: 3128.63	Time: 12m 59s
# --- Epoch 4/10 ---
# 	train avg_chi2: 3021.53	valid avg_chi2: 2450.38	Time: 12m 57s
# --- Epoch 5/10 ---
# 	train avg_chi2: 2529.64	valid avg_chi2: 1994.92	Time: 13m 6s
# --- Epoch 6/10 ---
# 	train avg_chi2: 2108.04	valid avg_chi2: 1895.92	Time: 12m 57s
# --- Epoch 7/10 ---
# 	train avg_chi2: 1792.24	valid avg_chi2: 1354.40	Time: 13m 2s
# --- Epoch 8/10 ---
# 	train avg_chi2: 1560.47	valid avg_chi2: 1188.59	Time: 12m 57s
# --- Epoch 9/10 ---
# 	train avg_chi2: 1399.37	valid avg_chi2: 1192.88	Time: 13m 5s
# --- Epoch 10/10 ---
# 	train avg_chi2: 1269.09	valid avg_chi2: 924.02	Time: 12m 54s
#
# Minimum (epoch-averaged) validation loss reached at epoch 10.

# %% [markdown]
# ## Plots: Training States

# %%
import numpy as np
import torch

from matplotlib import pyplot as plt
# %config InlineBackend.figure_format = 'retina'
plt.rc('font', size=16)

# %%
trainInfo = torch.load(emu.file_trainInfo)

# %%
trainInfo.keys()
# Out:
# dict_keys(['train_loss', 'valid_loss', 'epoch_train_loss', 'epoch_valid_loss', 'lr', 'best_epochID', 'best_model_wts'])

# %%
iter_tick = {}
for phase in ['train', 'valid']:
    iter_tick[phase] = np.array(range(len(trainInfo[f'{phase}_loss'])))/len(emu.dataloader[phase])

epoch_tick = np.array(range(len(trainInfo['epoch_train_loss'])))+0.5

# --------------------------

plt.figure(figsize=(16,10))

plt.subplot(211)

n = 1
plt.plot(iter_tick['train'][::n], trainInfo['train_loss'][::n], color='lightblue')
plt.plot(iter_tick['valid'][::n], trainInfo['valid_loss'][::n], color='gold')

plt.plot(epoch_tick, trainInfo['epoch_train_loss'], 'o--', label='train', color='b')
plt.plot(epoch_tick, trainInfo['epoch_valid_loss'], 'o--', label='valid', color='darkorange')

plt.ylabel('MSE loss = average $\chi^2$')

plt.legend()

#plt.xlim([10,20])
plt.ylim([0,12000])


plt.subplot(212)
plt.plot(epoch_tick, trainInfo['lr'], 'o--', label='train', color='b' )
plt.title('Learning Rate Decay')
plt.ylabel('lr')
plt.yscale('log')
plt.xlabel('epoch')


plt.tight_layout()

# %% [markdown]
# ## Check the Performance of the Best Trained Emulator

# %%
import torch
import pandas as pd
import pickle
from emu_Nx2pt.data_kits import dataTDataset
from torch.utils.data import DataLoader

# %%
filename_pco = '/home/hhg/Research/emu_Nx2pt/data/pco_0.1M.pkl'
dir_dataT = '/home/hhg/Research/emu_Nx2pt/data/dataT_0.1M/'

with open(filename_pco, 'rb') as handle:
    pco_samples = pickle.load(handle)

test_pco = pd.DataFrame(pco_samples)

test_dataset = dataTDataset(test_pco, dir_dataT, emu.startID, emu.endID)
dataloader = DataLoader(test_dataset, batch_size=512, shuffle=False, num_workers=16)

# %%
avg_test_chi2 = emu.test(dataloader)
avg_test_chi2
# Out:
# Test model with the best-trained model at epochID: 9
#
# ------ Run test loop ------
#
#   Number of galaxies: 100000 (196 batches)
#   Average chi2 of the test set: 915.54
# 915.5425346875

# %% [markdown]
# ### Visualize emulated dataV

# %%
trainInfo = torch.load(emu.file_trainInfo)
emu.model.load_state_dict(trainInfo['best_model_wts'])

# ---------------------------------------------------------------------------

# stateID = 7
# stateInfo = torch.load(emu.dir_checkpoints + f'/stateInfo_{stateID}.pth')
# emu.model.load_state_dict(stateInfo['model_state_dict'])
# Out:
# <All keys matched successfully>

# %%
pcoID, pco, dataT = test_dataset[0]
pco = pco.to(emu.device)

dataV_true = emu.L@dataT.numpy()
dataV_emu  = emu.gen_dataV(pco)

dataT_true = dataT.to('cpu').numpy()
dataT_emu  = emu.gen_dataT(pco)
chi2 = np.sum((dataT_true-dataT_emu)**2)

# %%
plt.figure(figsize=(16,10))
plt.subplots_adjust(hspace=0.01)

plt.subplot(311)
plt.plot(range(0,emu.endID), dataV_true)
plt.plot(range(0,emu.endID), dataV_emu, ls='-.')
plt.text(500, 1e-5, f"$\chi^2$={chi2:.2f}")

plt.yscale('log')
plt.ylabel('dataV')
plt.xlim([0, emu.endID])
_ = plt.xticks(range(0,emu.endID, 500),[])

plt.subplot(312)
plt.plot(range(0,emu.endID), dataV_true-dataV_emu)
plt.ylabel('residual')
plt.title('dataV$_{true}$ - dataV$_{emu}$')
_ = plt.xticks(range(0,emu.endID, 500),[])
plt.xlim([0, emu.endID])


plt.subplot(313)
dataV_diag_std = np.sqrt(emu.cov_masked.diagonal())[0:emu.endID]
plt.plot(range(0,emu.endID), abs(dataV_true-dataV_emu)/dataV_diag_std )
plt.title('(dataV$_{true}$ - dataV$_{emu}$)/$\sigma_{diag}$')
plt.ylabel('n-$\sigma$ difference')
plt.xlim([0, emu.endID])


plt.tight_layout()
