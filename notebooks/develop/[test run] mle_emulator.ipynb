# %%
import sys
dir_repo = '../../'
sys.path.append(dir_repo)

from emu_Nx2pt.utils import get_config_from_yaml
from emu_Nx2pt.mlp_emulator import MLP_Emulator

! rm -rf /home/hhg/Research/emu_Nx2pt/repo/emulator_Nx2pt/experiments/mlp_run0/

# %%
config = get_config_from_yaml(dir_repo+'configs/mlp_run0.yaml')
emu = MLP_Emulator(config=config)
# Out:
# ------ Parameters ------
#
# exp_name : mlp_run0
# cuda : True
# ngpu : 1
# gpu_device : 0
# workers : 16
# dir_output : /home/hhg/Research/emu_Nx2pt/repo/emulator_Nx2pt/experiments
# dir_dataT : /home/hhg/Research/emu_Nx2pt/data/train_1M/
# filename_pco : /home/hhg/Research/emu_Nx2pt/data/pco_train_1000000.pkl
# startID : 0
# endID : 800000
# f_train : 0.8
# seed : 3
# Nhidden : 128
# Nblocks : 2
# num_epochs : 70
# batch_size : 128
# lr : 0.01
# beta1 : 0.5
# beta2 : 0.999
# step_size : 30
# gamma : 0.5
# early_stop_threshold : 10
# file_cov : /home/hhg/Research/emu_Nx2pt/data/cov3500.pkl
# file_mask : /home/hhg/Research/emu_Nx2pt/data/10x2pt_RomanxSO_fid_mask.txt
#
# ------ Device ------
#
# cuda:0
#
# ------ Prepare Data ------
#
# Number of train samples: 640000 (5000 batches)
# Number of valid samples: 160000 (1250 batches)
#
# ------ Build Model ------
#
# MLP(
#   (in_layer): Sequential(
#     (0): Linear(in_features=17, out_features=128, bias=True)
#     (1): ReLU()
#   )
#   (mid_layers): ModuleDict(
#     (block_0): Sequential(
#       (0): Linear(in_features=128, out_features=128, bias=True)
#       (1): ReLU()
#     )
#     (block_1): Sequential(
#       (0): Linear(in_features=128, out_features=128, bias=True)
#       (1): ReLU()
#     )
#   )
#   (out_layer): Linear(in_features=128, out_features=3132, bias=True)
# )
#
# Number of trainable parameters: 439356

# %%
emu.train()
# Out:
# ------ Create experiment directory ------
#
# Training information will be stored at :
#  	 /home/hhg/Research/emu_Nx2pt/repo/emulator_Nx2pt/experiments/mlp_run0
# --- Epoch 1/70 ---
# 	train avg_chi2: 56328.79	valid avg_chi2: 28163.39	Time: 0m 23s
# --- Epoch 2/70 ---
# 	train avg_chi2: 18362.66	valid avg_chi2: 13958.61	Time: 0m 26s
# --- Epoch 3/70 ---
# 	train avg_chi2: 12698.02	valid avg_chi2: 9457.64	Time: 0m 26s
# --- Epoch 4/70 ---
# 	train avg_chi2: 10618.54	valid avg_chi2: 6969.01	Time: 0m 24s
# --- Epoch 5/70 ---
# 	train avg_chi2: 9092.10	valid avg_chi2: 20018.65	Time: 0m 23s
# --- Epoch 6/70 ---
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_198604/3989874308.py in <module>
# ----> 1 emu.train()
#
# ~/Research/emu_Nx2pt/repo/emulator_Nx2pt/notebooks/develop/../../emu_Nx2pt/mlp_emulator.py in train(self)
#     137
#     138             since = time.time()
# --> 139             self._train_one_epoch()
#     140             self._save_checkpoint(epochID)
#     141
#
# ~/Research/emu_Nx2pt/repo/emulator_Nx2pt/notebooks/develop/../../emu_Nx2pt/mlp_emulator.py in _train_one_epoch(self)
#      99                     if phase == 'train':
#     100                         loss.backward()
# --> 101                         self.optimizer.step()
#     102
#     103                 self.trainInfo[f'{phase}_loss'].append( loss.item()/inputs.size(0) )
#
# /usr/local/lib/python3.9/dist-packages/torch/optim/lr_scheduler.py in wrapper(*args, **kwargs)
#      63                 instance._step_count += 1
#      64                 wrapped = func.__get__(instance, cls)
# ---> 65                 return wrapped(*args, **kwargs)
#      66
#      67             # Note that the returned function here is no longer a bound method,
#
# /usr/local/lib/python3.9/dist-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#      86                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#      87                 with torch.autograd.profiler.record_function(profile_name):
# ---> 88                     return func(*args, **kwargs)
#      89             return wrapper
#      90
#
# /usr/local/lib/python3.9/dist-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      26         def decorate_context(*args, **kwargs):
#      27             with self.__class__():
# ---> 28                 return func(*args, **kwargs)
#      29         return cast(F, decorate_context)
#      30
#
# /usr/local/lib/python3.9/dist-packages/torch/optim/adam.py in step(self, closure)
#     131                     state_steps.append(state['step'])
#     132
# --> 133             F.adam(params_with_grad,
#     134                    grads,
#     135                    exp_avgs,
#
# /usr/local/lib/python3.9/dist-packages/torch/optim/_functional.py in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps)
#      96         step_size = lr / bias_correction1
#      97
# ---> 98         param.addcdiv_(exp_avg, denom, value=-step_size)
#      99
#     100
#
# KeyboardInterrupt:

# %% [markdown]
# ## Plots: Training States

# %%
import numpy as np
import torch

from matplotlib import pyplot as plt
# %config InlineBackend.figure_format = 'retina'
plt.rc('font', size=16)

# %%
trainInfo = torch.load(emu.file_trainInfo)

# %%
trainInfo.keys()
# Out:
# dict_keys(['train_loss', 'valid_loss', 'epoch_train_loss', 'epoch_valid_loss', 'lr', 'best_epochID', 'best_model_wts'])

# %%
iter_tick = {}
for phase in ['train', 'valid']:
    iter_tick[phase] = np.array(range(len(trainInfo[f'{phase}_loss'])))/len(emu.dataloader[phase])

epoch_tick = np.array(range(len(trainInfo['epoch_train_loss'])))+0.5

# --------------------------

plt.figure(figsize=(16,10))

plt.subplot(211)

n = 1
plt.plot(iter_tick['train'][::n], trainInfo['train_loss'][::n], color='lightblue')
plt.plot(iter_tick['valid'][::n], trainInfo['valid_loss'][::n], color='gold')

plt.plot(epoch_tick, trainInfo['epoch_train_loss'], 'o--', label='train', color='b')
plt.plot(epoch_tick, trainInfo['epoch_valid_loss'], 'o--', label='valid', color='darkorange')

plt.ylabel('MSE loss = average $\chi^2$')

plt.legend()

#plt.xlim([10,20])
plt.ylim([0,20000])


plt.subplot(212)
plt.plot(epoch_tick, trainInfo['lr'], 'o--', label='train', color='b' )
plt.title('Learning Rate Decay')
plt.ylabel('lr')
plt.yscale('log')
plt.xlabel('epoch')


plt.tight_layout()

# %% [markdown]
# ## Check the Performance of the Best Trained Emulator

# %%
import torch
import pandas as pd
import pickle
from emu_Nx2pt.data_kits import dataTDataset
from torch.utils.data import DataLoader

# %%
startID, endID = 900000, 900100  # 1000000
filename_pco = '/home/hhg/Research/emu_Nx2pt/data/pco_train_1000000.pkl'
dir_dataT = '/home/hhg/Research/emu_Nx2pt/data/train_1M/'

with open(filename_pco, 'rb') as handle:
    pco_samples = pickle.load(handle)

test_pco = pd.DataFrame(pco_samples).iloc[startID:endID]

testID = list(range(startID, endID))
test_dataset = dataTDataset(testID, test_pco, dir_dataT)
dataloader = DataLoader(test_dataset, batch_size=1, shuffle=False, num_workers=16)

# %%
avg_test_chi2 = emu.test(dataloader)
avg_test_chi2
# Out:
# ------ Run test loop ------
#
#   Number of galaxies: 100 (100 batches)
# Average chi2 of the test set: 78502.88
# 78502.87872558594

# %% [markdown]
# ### Visualize emulated dataV

# %%
trainInfo = torch.load(emu.file_trainInfo)
emu.model.load_state_dict(trainInfo['best_model_wts'])

# ---------------------------------------------------------------------------

# stateID = 7
# stateInfo = torch.load(emu.dir_checkpoints + f'/stateInfo_{stateID}.pth')
# emu.model.load_state_dict(stateInfo['model_state_dict'])
# Out:
# <All keys matched successfully>

# %%
pcoID, pco, dataT = test_dataset[0]
pco = pco.to(emu.device)

dataV_true = emu.L@dataT.numpy()
dataV_emu  = emu.gen_dataV(pco)

dataT_true = dataT.to('cpu').numpy()
dataT_emu  = emu.gen_dataT(pco)
chi2 = np.sum((dataT_true-dataT_emu)**2)

# %%
plt.figure(figsize=(16,10))
plt.subplots_adjust(hspace=0.01)

plt.subplot(311)
plt.plot(range(0,emu.Nout), dataV_true)
plt.plot(range(0,emu.Nout), dataV_emu, ls='-.')
plt.text(500, 1e-16, f"$\chi^2$={chi2:.2f}")

plt.yscale('log')
plt.ylabel('dataV')
plt.xlim([0, emu.Nout])
_ = plt.xticks(range(0,emu.Nout, 500),[])

plt.subplot(312)
plt.plot(range(0,emu.Nout), dataV_true-dataV_emu)
plt.ylabel('residual')
plt.title('dataV$_{true}$ - dataV$_{emu}$')
_ = plt.xticks(range(0,emu.Nout, 500),[])
plt.xlim([0, emu.Nout])


plt.subplot(313)
dataV_diag_std = np.sqrt(emu.cov_masked.diagonal())
plt.plot(range(0,emu.Nout), abs(dataV_true-dataV_emu)/dataV_diag_std )
plt.title('(dataV$_{true}$ - dataV$_{emu}$)/$\sigma_{diag}$')
plt.ylabel('n-$\sigma$ difference')
plt.xlim([0, emu.Nout])


plt.tight_layout()
